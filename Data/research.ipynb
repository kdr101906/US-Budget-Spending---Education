# %%
import pandas as pd
df = pd.read_csv('All_Contracts.csv')
row = df.iloc[36069]
row['total_dollars_obligated']
# Out:
# /tmp/ipykernel_2129926/3297401973.py:2: DtypeWarning: Columns (3,5,8,26,27,47,52,61,68,71,72,81,87,88,89,90,91,92,97,98,99,101,102,107,108,115,135,136,139,140,164,165,170,171,172,179,180) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('All_Contracts.csv')
# np.float64(84508.62)
